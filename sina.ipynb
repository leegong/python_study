# %% [markdown]
# <a href="https://colab.research.google.com/github/leegong/python_study/blob/master/sina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import feedparser


d = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=linkNewsTopBold&max=5&order=document&guid=0')
print ()
for post in d.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

e = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=list_14&max=5&order=document&guid=0')
print ()
for post in e.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

f = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=list_14&max=5&order=document&guid=0')
print ()
for post in f.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

g = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=dot+topli14&max=5&order=document&guid=0')
print ()
for post in g.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

h = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=list_14_noBg&max=5&order=document&guid=0')
print ()
for post in h.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

i = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=exclsv_hot_ls&max=5&order=document&guid=0')
print ()
for post in i.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

j = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=list_12+link_c666&max=5&order=document&guid=0')
print ()
for post in j.entries:
    print (post.title + ": \n" + post.link + " \n ")
# Out:
# 共谋人民幸福 百年大党这样选择:
# https://news.sina.com.cn/c/xl/2021-07-07/doc-ikqcfnca5538917.shtml
#
# 习近平同捷克总统通电话:
# https://news.sina.com.cn/c/xl/2021-07-07/doc-ikqciyzk4122412.shtml
#
# 同希腊总理通电话:
# https://news.sina.com.cn/c/xl/2021-07-07/doc-ikqcfnca5524844.shtml
#
# 瑞丽市长:有信心把传染源控制在姐告、瑞丽:
# https://news.sina.com.cn/c/2021-07-07/doc-ikqciyzk4138805.shtml
#
# 国常会重磅定调 超预期提降准！:
# https://news.sina.com.cn/c/2021-07-08/doc-ikqciyzk4145454.shtml
#
# Press Enter to continue...
#
# 菲律宾运输机坠毁 台军慌了:
# https://news.sina.cn/zt_d/flbjjzh
#
# 警方曝光诈骗团伙“笔记”：这种微信头像的不下手:
# https://news.sina.com.cn/s/2021-07-08/doc-ikqciyzk4176669.shtml
#
# 国常会释放适时降准信号：为何降 何时降 怎么降？:
# https://news.sina.com.cn/o/2021-07-08/doc-ikqciyzk4175153.shtml
#
# 高考前1天父亲去世男生打工挣学费 每天工作14小时:
# https://k.sina.com.cn/article_5637065453_m14ffecaed033012kk4.html?from=edu
#
# 女子家门口连续几天收到新鲜蔬菜 一查监控暖哭了:
# https://k.sina.com.cn/article_3057540037_mb63e5bc5053017pue.html?from=news&subch=onews
#
# Press Enter to continue...
#
# 菲律宾运输机坠毁 台军慌了:
# https://news.sina.cn/zt_d/flbjjzh
#
# 警方曝光诈骗团伙“笔记”：这种微信头像的不下手:
# https://news.sina.com.cn/s/2021-07-08/doc-ikqciyzk4176669.shtml
#
# 国常会释放适时降准信号：为何降 何时降 怎么降？:
# https://news.sina.com.cn/o/2021-07-08/doc-ikqciyzk4175153.shtml
#
# 高考前1天父亲去世男生打工挣学费 每天工作14小时:
# https://k.sina.com.cn/article_5637065453_m14ffecaed033012kk4.html?from=edu
#
# 女子家门口连续几天收到新鲜蔬菜 一查监控暖哭了:
# https://k.sina.com.cn/article_3057540037_mb63e5bc5053017pue.html?from=news&subch=onews
#
# Press Enter to continue...
#
# 有了短缺保障机制 廉价救命药为何依然出现“药荒”:
# https://news.sina.com.cn/o/2021-07-07/doc-ikqciyzk4125576.shtml
#
# :
# http://health.sina.com.cn/
#
# 华森制药2药品获药品再注册批准:
# https://med.sina.com/article_detail_103_2_101902.html
#
# 久坐的危害:
# https://med.sina.com/health/article_detail_103_1_8494.html
#
# Press Enter to continue...
#
# 有了短缺保障机制 廉价救命药为何依然出现“药荒”:
# https://news.sina.com.cn/o/2021-07-07/doc-ikqciyzk4125576.shtml
#
# “喀布尔来的航班22确诊”最感动反转：原来是撤侨！:
# https://news.sina.com.cn/c/2021-07-07/doc-ikqcfnca5512081.shtml
#
# 针对中国疫苗 CNN这次说了句公道话！:
# https://news.sina.com.cn/o/2021-07-07/doc-ikqciyzk4093814.shtml
#
# 英媒：台湾拟修订计划强化“国防供应链”:
# https://news.sina.com.cn/o/2021-07-07/doc-ikqciyzk4044335.shtml
#
# 又是“德尔塔” 云南瑞丽部分病例基因测序结果公布:
# https://news.sina.com.cn/c/2021-07-07/doc-ikqciyzk4041219.shtml
#
# Press Enter to continue...
#
# 夏日极端天气，如何防范？:
# https://k.sina.com.cn/article_2699180811_a0e23b0b00100wwlp.html
#
# 这届毕业生的租房态度变了？:
# https://k.sina.com.cn/article_2699180811_a0e23b0b00100wp9p.html?kdurlshow=1&wm=3049_0047&from=estate
#
# 3个月的太空生活，很自由！:
# https://k.sina.cn/article_2699180811_a0e23b0b00100wnta.html
#
# Press Enter to continue...
#
# 重拳整治电信诈骗 工信部推进"断卡"等行动:
# https://news.sina.com.cn/gov/2021-07-07/doc-ikqciyzk3997908.shtml
#
# 国家发改委：不得新建500米以上超高层建筑:
# https://news.sina.com.cn/gov/2021-07-07/doc-ikqcfnca5414883.shtml
#
# 外媒:美驻巴格达使馆拉响警报 防空系统启动应对攻击:
# https://mil.news.sina.com.cn/world/2021-07-08/doc-ikqciyzk4179034.shtml
#
# “七七事变”亲历者：不到300米的桥 他走了近70年:
# https://mil.news.sina.com.cn/history/2021-07-07/doc-ikqcfnca5500026.shtml
#
# 俄罗斯海军军舰在黑海追踪一艘西班牙参加军演巡逻舰:
# https://mil.news.sina.com.cn/world/2021-07-07/doc-ikqciyzk4098837.shtml

# %%
# !pip install feedparser

import feedparser


d = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=linkNewsTopBold&max=5&order=document&guid=0')
print ()
for post in d.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

e = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=list_14&max=5&order=document&guid=0')
print ()
for post in e.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

f = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=list_14&max=5&order=document&guid=0')
print ()
for post in f.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

g = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=dot+topli14&max=5&order=document&guid=0')
print ()
for post in g.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

h = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=list_14_noBg&max=5&order=document&guid=0')
print ()
for post in h.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

i = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=exclsv_hot_ls&max=5&order=document&guid=0')
print ()
for post in i.entries:
    print (post.title + ": \n" + post.link + " \n ")

input("Press Enter to continue...")

j = feedparser.parse('http://createfeed.fivefilters.org/extract.php?url=https%3A%2F%2Fnews.sina.com.cn%2F&in_id_or_class=list_12+link_c666&max=5&order=document&guid=0')
print ()
for post in j.entries:
    print (post.title + ": \n" + post.link + " \n ")
# Out:
# Collecting feedparser
#   Downloading https://files.pythonhosted.org/packages/d8/b2/15bf6781a861bbc5dd801d467f26448fb322bfedcd30f2e62b148d104dfb/feedparser-6.0.8-py3-none-any.whl (81kB)
#      |████████████████████████████████| 81kB 4.9MB/s
# Collecting sgmllib3k
#   Downloading https://files.pythonhosted.org/packages/9e/bd/3704a8c3e0942d711c1299ebf7b9091930adae6675d7c8f476a7ce48653c/sgmllib3k-1.0.0.tar.gz
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-cp37-none-any.whl size=6067 sha256=34630296ec305a84b3fd24f986c8383946b7953fe879053b0b5e93b09602d7de
#   Stored in directory: /root/.cache/pip/wheels/f1/80/5a/444ba08a550cdd241bd9baf8bae44be750efe370adb944506a
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.8 sgmllib3k-1.0.0
#
# 共谋人民幸福 百年大党这样选择:
# https://news.sina.com.cn/c/xl/2021-07-07/doc-ikqcfnca5538917.shtml
#
# 习近平同捷克总统通电话:
# https://news.sina.com.cn/c/xl/2021-07-07/doc-ikqciyzk4122412.shtml
#
# 同希腊总理通电话:
# https://news.sina.com.cn/c/xl/2021-07-07/doc-ikqcfnca5524844.shtml
#
# 瑞丽市长:有信心把传染源控制在姐告、瑞丽:
# https://news.sina.com.cn/c/2021-07-07/doc-ikqciyzk4138805.shtml
#
# 国常会重磅定调 超预期提降准！:
# https://news.sina.com.cn/c/2021-07-08/doc-ikqciyzk4145454.shtml
#
# Press Enter to continue...
#
# 菲律宾运输机坠毁 台军慌了:
# https://news.sina.cn/zt_d/flbjjzh
#
# 警方曝光诈骗团伙“笔记”：这种微信头像的不下手:
# https://news.sina.com.cn/s/2021-07-08/doc-ikqciyzk4176669.shtml
#
# 国常会释放适时降准信号：为何降 何时降 怎么降？:
# https://news.sina.com.cn/o/2021-07-08/doc-ikqciyzk4175153.shtml
#
# 高考前1天父亲去世男生打工挣学费 每天工作14小时:
# https://k.sina.com.cn/article_5637065453_m14ffecaed033012kk4.html?from=edu
#
# 女子家门口连续几天收到新鲜蔬菜 一查监控暖哭了:
# https://k.sina.com.cn/article_3057540037_mb63e5bc5053017pue.html?from=news&subch=onews
